# %%
#importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

#importing our cancer dataset
dataset = pd.read_csv('test.csv')
X = dataset.iloc[:, 1:20].values
Y = dataset.iloc[:, 20].values

# %%
#show the first 5 lines of the whole dataset
dataset.head(5)
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        12.40         17.68           81.47      467.8          0.10540
# 1        11.81         17.39           75.27      428.9          0.10070
# 2        15.00         15.51           97.45      684.5          0.08371
# 3        11.51         23.93           74.52      403.5          0.09261
# 4        12.62         23.97           81.35      496.4          0.07903
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.13160         0.07741              0.02799         0.1811
# 1           0.05562         0.02353              0.01553         0.1718
# 2           0.10960         0.06505              0.03780         0.1881
# 3           0.10210         0.11120              0.04105         0.1388
# 4           0.07529         0.05438              0.02036         0.1514
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                 0.07102  ...         12.88          22.91            89.61
# 1                 0.05780  ...         12.57          26.48            79.57
# 2                 0.05907  ...         16.41          19.31           114.20
# 3                 0.06570  ...         12.48          37.16            82.28
# 4                 0.06019  ...         14.20          31.31            90.67
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0       515.8            0.1450             0.2629          0.24030
# 1       489.5            0.1356             0.1000          0.08803
# 2       808.2            0.1136             0.3627          0.34020
# 3       474.2            0.1298             0.2517          0.36300
# 4       624.0            0.1227             0.3454          0.39110
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0               0.07370          0.2556                  0.09359
# 1               0.04306          0.3200                  0.06576
# 2               0.13790          0.2954                  0.08362
# 3               0.09653          0.2112                  0.08732
# 4               0.11800          0.2826                  0.09585
#
# [5 rows x 30 columns]

# %%
#Preparing the data
print("Cancer data set dimensions : {}".format(dataset.shape))
# Out:
# Cancer data set dimensions : (20, 30)

# %%
#Basic statistics of the data
dataset.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count    20.000000     20.000000       20.000000    20.000000
# mean     14.970000     21.935000       98.323000   726.795000
# std       3.399361      5.114454       23.545899   346.058473
# min      10.200000     14.260000       65.050000   321.200000
# 25%      12.565000     17.622500       81.257500   489.250000
# 50%      14.475000     22.360000       94.415000   642.450000
# 75%      16.712500     25.605000      109.575000   867.325000
# max      21.560000     30.620000      143.000000  1479.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count        20.000000         20.000000       20.000000            20.000000
# mean          0.096204          0.123278        0.126805             0.062668
# std           0.012209          0.059831        0.094101             0.043526
# min           0.074490          0.035580        0.000000             0.000000
# 25%           0.084340          0.079790        0.056900             0.026083
# 50%           0.098545          0.111100        0.101855             0.050415
# 75%           0.105875          0.162875        0.195175             0.097223
# max           0.114100          0.223600        0.317400             0.147400
#
#        symmetry_mean  fractal_dimension_mean  ...  radius_worst  \
# count      20.000000               20.000000  ...     20.000000
# mean        0.182360                0.062301  ...     17.052000
# std         0.033877                0.006277  ...      4.583936
# min         0.106000                0.055020  ...     11.480000
# 25%         0.157675                0.056418  ...     13.585000
# 50%         0.184600                0.060950  ...     15.825000
# 75%         0.210125                0.068837  ...     19.132500
# max         0.252100                0.072540  ...     25.730000
#
#        texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# count      20.000000        20.000000    20.00000         20.000000
# mean       28.731500       115.544500   954.66500          0.131382
# std         6.956209        32.602307   531.60205          0.021607
# min        19.080000        75.190000   403.70000          0.092670
# 25%        24.080000        89.425000   569.05000          0.115925
# 50%        28.105000       109.750000   759.70000          0.135450
# 75%        33.407500       129.900000  1140.25000          0.141750
# max        42.790000       179.100000  2027.00000          0.177700
#
#        compactness_worst  concavity_worst  concave points_worst  \
# count          20.000000        20.000000             20.000000
# mean            0.324794         0.397396              0.145571
# std             0.202530         0.290270              0.081795
# min             0.054940         0.000000              0.000000
# 25%             0.188475         0.227375              0.090823
# 50%             0.286150         0.351000              0.139850
# 75%             0.399700         0.533400              0.225100
# max             0.791700         1.170000              0.254300
#
#        symmetry_worst  fractal_dimension_worst
# count       20.000000                20.000000
# mean         0.282305                 0.087355
# std          0.071135                 0.021236
# min          0.156600                 0.059050
# 25%          0.224200                 0.072230
# 50%          0.286700                 0.083415
# 75%          0.307975                 0.096570
# max          0.466700                 0.140900
#
# [8 rows x 30 columns]

# %%
#Training the model
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.05)

# %%
#Plot the relationship between the variables using pairplot
sns.pairplot(dataset)

# %%
#Separate Feature and Target matrices
x = data.iloc[:,:-1].values
y = data.iloc[:,1].values

# %%
#Define the Machine Learning Algorithm
ml = LogisticRegression()

# %%
#Train the Machine Learning Algorithm (Learning)
ml.fit(x_train,y_train)

# %%
#Test the Machine Learning Algorithm (Prediction)
y_pred = ml.predict(x_test)

# %%
plt.scatter(x_test,y_test,color= 'red', marker='+')
plt.scatter(x_test,y_pred,color='blue', marker='.')
plt.xlabel("Number of Patients")
plt.ylabel("Malignant =1, Benign = 0")

# %%
ml.score(x_test,y_test)

# %%
confusion_matrix(y_test,y_pred)

# %%
df.to_csv("C:\Users\PC GAMING\Desktop\MACHI\SAGOT.CSV")
